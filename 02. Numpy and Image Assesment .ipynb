# %% [markdown]
# # <span style = "color:blue"> NumPy and Image Assesment <span>

# %% [markdown]
# ***

# %% [markdown]
# ## <i> Complete the tasks below </i>

# %% [markdown]
# ### Import numpy

# %%
import numpy as np

# %% [markdown]
# ### Create a 5 by 5 array where every number is a 10

# %%
arr = np.ones((5,5))*10

# %%
arr
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %% [markdown]
# ### Run the cell below to create an array of random numbers and see if you can figure out how it works

# %%
random_array = np.random.randint(1,50, size = 20)

# %%
random_array
# Out:
# array([18, 33, 30, 11, 46, 11, 10,  2, 38, 22, 48, 35, 38, 31, 43,  2,  1,
#        49, 19, 14])

# %% [markdown]
# ### What are the smallest and largest values in this array?

# %%
smallest_value = np.min(random_array)

# %%
smallest_value
# Out:
# 1

# %%
largest_value = np.max(random_array)

# %%
largest_value
# Out:
# 49

# %% [markdown]
# ### Import matplotlib and PIL

# %%
import matplotlib.pyplot as plt
import PIL

# %% [markdown]
# ### Use PIL and Matplotlib to read and Display the image 'cat_image.jpg'

# %% [markdown]
# #### Using PIL

# %%
from PIL import Image
pic = Image.open("image.jpg")

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2121x1414>

# %% [markdown]
# #### Using Matplotlib

# %%
a = plt.imread('image.jpg')

# %%
plt.imshow(a)

# %% [markdown]
# ### Use slicing to set the Red and Green channels of the picture to 0, then use imshow() to show the isolated blue channel

# %%
pic_arr = np.asarray(pic)

# %%
pic_copy = pic_arr.copy()

# %%
pic_copy[:,:,0] = 0
pic_copy[:,:,1] = 0

# %%
plt.imshow(pic_copy)

# %% [markdown]
# ***

# %% [markdown]
# ***
